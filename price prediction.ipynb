# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car.csv')

# %%
df.head()
# Out:
#                                      name   company  year  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007  45,000 kms
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006      40 kms
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  22,000 kms
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  28,000 kms
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  36,000 kms
#
#   fuel_type          Price
# 0    Petrol         80,000
# 1    Diesel       4,25,000
# 2    Petrol  Ask For Price
# 3    Petrol       3,25,000
# 4    Diesel       5,75,000

# %%
df.shape
# Out:
# (892, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   kms_driven  840 non-null    object
#  4   fuel_type   837 non-null    object
#  5   Price       892 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# kms_driven    52
# fuel_type     55
# Price          0
# dtype: int64

# %%
df.sample(10)
# Out:
#                                     name   company  year  kms_driven  \
# 101          Mahindra XUV500 W8 AWD 2013  Mahindra  2013  38,000 kms
# 289                Fiat Petra ELX 1.2 PS      Fiat  2008  65,000 kms
# 228            Mahindra Thar CRDe 4x4 AC  Mahindra  2016  29,000 kms
# 192                 Maruti Suzuki Zen VX    Maruti  2000  60,000 kms
# 370  Force Motors Force One LX ABS 7 STR     Force  2015   3,200 kms
# 277             Renault Kwid 1.0 RXT AMT   Renault  2018  10,000 kms
# 248         Hyundai i20 Active 1.4L SX O   Hyundai  2015  37,000 kms
# 462                 Mahindra Scorpio S10  Mahindra  2015  97,200 kms
# 249                        Mini Cooper S      Mini  2013  13,000 kms
# 120    Maruti Suzuki Swift VXi 1.2 BS IV    Maruti  2013  13,349 kms
#
#     fuel_type      Price
# 101    Diesel   7,01,000
# 289    Petrol     75,000
# 228    Diesel   7,30,000
# 192    Petrol     55,000
# 370    Diesel   5,80,000
# 277    Petrol   3,49,999
# 248    Diesel   5,35,000
# 462    Diesel   9,00,000
# 249    Petrol  18,91,111
# 120    Petrol   3,72,000

# %%
df = df[df['year'].str.isnumeric()]

# %%
df.shape
# Out:
# (842, 6)

# %%
df['year'] = df['year'].astype(int)

# %%
df = df[df['Price']!='Ask For Price']

# %%
df.shape
# Out:
# (819, 6)

# %%
df['Price'] = df['Price'].str.replace(',','').astype(int)

# %%
df.head()
# Out:
#                                      name   company  year  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007  45,000 kms
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006      40 kms
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  28,000 kms
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  36,000 kms
# 6                               Ford Figo      Ford  2012  41,000 kms
#
#   fuel_type   Price
# 0    Petrol   80000
# 1    Diesel  425000
# 3    Petrol  325000
# 4    Diesel  575000
# 6    Diesel  175000

# %%
df['kms_driven'] = df['kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
df.head()
# Out:
#                                      name   company  year kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007      45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014      28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014      36000
# 6                               Ford Figo      Ford  2012      41000
#
#   fuel_type   Price
# 0    Petrol   80000
# 1    Diesel  425000
# 3    Petrol  325000
# 4    Diesel  575000
# 6    Diesel  175000

# %%
df = df[df['kms_driven'].str.isnumeric()]

# %%
df['kms_driven'] = df['kms_driven'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int32
#  3   kms_driven  817 non-null    int32
#  4   fuel_type   816 non-null    object
#  5   Price       817 non-null    int32
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
df=df[~df['fuel_type'].isna()]

# %%
df['name']=df['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %%
df.head()
# Out:
#                      name   company  year  kms_driven fuel_type   Price
# 0     Hyundai Santro Xing   Hyundai  2007       45000    Petrol   80000
# 1     Mahindra Jeep CL550  Mahindra  2006          40    Diesel  425000
# 3       Hyundai Grand i10   Hyundai  2014       28000    Petrol  325000
# 4  Ford EcoSport Titanium      Ford  2014       36000    Diesel  575000
# 6               Ford Figo      Ford  2012       41000    Diesel  175000

# %%
df.describe()
# Out:
#               year     kms_driven         Price
# count   816.000000     816.000000  8.160000e+02
# mean   2012.444853   46275.531863  4.117176e+05
# std       4.002992   34297.428044  4.751844e+05
# min    1995.000000       0.000000  3.000000e+04
# 25%    2010.000000   27000.000000  1.750000e+05
# 50%    2013.000000   41000.000000  2.999990e+05
# 75%    2015.000000   56818.500000  4.912500e+05
# max    2019.000000  400000.000000  8.500003e+06

# %%
df.Price.max()
# Out:
# 8500003

# %%
df = df[df['Price']<5000000]

# %%
df.sample(5)
# Out:
#                   name  company  year  kms_driven fuel_type   Price
# 328        Honda Amaze    Honda  2014       35000    Petrol  274999
# 333  Hyundai Elite i20  Hyundai  2016        9000    Petrol  549999
# 666    Tata Indica eV2     Tata  2015       60105    Diesel  140000
# 44         Honda Amaze    Honda  2013       46000    Diesel  284999
# 680       Tata Zest XE     Tata  2018      102563    Diesel  450000

# %%
x = df.drop(columns = 'Price')
y = df['Price']

# %%
x
# Out:
#                        name   company  year  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 6                 Ford Figo      Ford  2012       41000    Diesel
# ..                      ...       ...   ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 885          Tata Indica V2      Tata  2009       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 888            Tata Zest XM      Tata  2018       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [815 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 815, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((652, 5), (163, 5))

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe = OneHotEncoder()
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
import pickle

# %%
pickle.dump(ohe,open('encoder.pkl','wb'))

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\Lab\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(pipe, f)

# %%
y_pred = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6589903982296942

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 302

# %%
scores[np.argmax(scores)]
# Out:
# 0.8991139955370199

# %%
pipe.predict(pd.DataFrame(columns = X_test.columns,data=np.array(['Tata Indigo eCS','Tata',2015,10000,'Petrol']).reshape(1,5)))
# Out:
# array([246668.96195009])
